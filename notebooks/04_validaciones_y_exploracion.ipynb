# %%
import snowflake.connector
import os
import pandas as pd
from snowflake.connector.errors import NotSupportedError

def sf_query(sql: str):
    """
    Ejecuta UNA sola sentencia SQL en Snowflake.
    - Si trae resultados, devuelve un DataFrame.
    - Si no, imprime confirmación.
    Maneja SHOW/DESCRIBE/SELECT aunque fetch_pandas_all no esté soportado.
    """
    conn = snowflake.connector.connect(
        user=os.getenv("SNOWFLAKE_USER"),
        password=os.getenv("SNOWFLAKE_PASSWORD"),
        account=os.getenv("SNOWFLAKE_HOST").split(".snowflakecomputing.com")[0],
        warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
        database=os.getenv("SNOWFLAKE_DATABASE"),
        role=os.getenv("SNOWFLAKE_ROLE"),
    )
    try:
        cur = conn.cursor()
        # Intentamos usar Arrow para que fetch_pandas_all funcione
        try:
            cur.execute("ALTER SESSION SET QUERY_RESULT_FORMAT=ARROW")
        except Exception:
            pass  # si falla, igual seguimos (haremos fallback)

        cur.execute(sql)

        if cur.description:  # hay result set (SELECT/SHOW/DESCRIBE)
            try:
                df = cur.fetch_pandas_all()  # rápido si hay Arrow/pyarrow
            except NotSupportedError:
                # Fallback sin Arrow
                rows = cur.fetchall()
                cols = [d[0] for d in cur.description]
                df = pd.DataFrame(rows, columns=cols)
            finally:
                cur.close()
            return df
        else:
            cur.close()
            print("Executed successfully.")
    finally:
        conn.close()

# %%
# Verificar contexto actual
sf_query("SELECT CURRENT_DATABASE(), CURRENT_SCHEMA(), CURRENT_WAREHOUSE(), CURRENT_ROLE();")
# Out:
#   CURRENT_DATABASE() CURRENT_SCHEMA() CURRENT_WAREHOUSE() CURRENT_ROLE()
# 0           DM_PSET3             None               WH_DM       SYSADMIN

# %%
sf_query("SHOW VIEWS IN SCHEMA ANALYTICS;")
# Out:
#                         created_on         name reserved database_name  \
# 0 2025-10-23 08:41:54.807000-07:00  OBT_TRIPS_V               DM_PSET3
#
#   schema_name     owner comment  \
# 0   ANALYTICS  SYSADMIN
#
#                                                 text is_secure  \
# 0  CREATE OR REPLACE VIEW ANALYTICS.OBT_TRIPS_V A...     false
#
#   is_materialized owner_role_type change_tracking
# 0           false            ROLE             OFF

# %%
# Conteo rápido
sf_query("SELECT COUNT(*) AS cnt FROM ANALYTICS.OBT_TRIPS_V;")
# Out:
#          CNT
# 0  851622729

# %%
sf_query("""
CREATE OR REPLACE VIEW ANALYTICS.OBT_TRIPS_CLEAN_V AS
SELECT *
FROM ANALYTICS.OBT_TRIPS_V
WHERE trip_minutes BETWEEN 1 AND 240
  AND trip_distance > 0 AND trip_distance <= 100
  AND tip_pct BETWEEN 0 AND 1;
""")
# Out:
#                                          status
# 0  View OBT_TRIPS_CLEAN_V successfully created.

# %%
sf_query("""
SELECT
  COUNT(*) AS total_clean,
  ROUND(COUNT(*) / 851622729 * 100, 2) AS pct_sobre_total
FROM ANALYTICS.OBT_TRIPS_CLEAN_V;
""")
# Out:
#    TOTAL_CLEAN PCT_SOBRE_TOTAL
# 0    838263783           98.43

# %%
sf_query("""
SELECT service_type,
       ROUND(AVG(trip_minutes),1) AS avg_min,
       ROUND(AVG(trip_distance),2) AS avg_dist,
       ROUND(AVG(tip_pct),3) AS avg_tip,
       COUNT(*) AS n
FROM ANALYTICS.OBT_TRIPS_CLEAN_V
GROUP BY 1
ORDER BY 1;
""")
# Out:
#   SERVICE_TYPE AVG_MIN  AVG_DIST  AVG_TIP          N
# 0        green    14.0      3.05    0.093   66081773
# 1       yellow    14.7      3.09    0.157  772182010

# %%
sf_query("""
SELECT pickup_hour,
       service_type,
       COUNT(*) AS n,
       ROUND(AVG(trip_minutes),1) AS avg_min,
       ROUND(AVG(trip_distance),2) AS avg_dist,
       ROUND(AVG(tip_pct),3) AS avg_tip
FROM ANALYTICS.OBT_TRIPS_CLEAN_V
GROUP BY 1,2
ORDER BY 1,2;
""")
# Out:
#     PICKUP_HOUR SERVICE_TYPE         N AVG_MIN  AVG_DIST  AVG_TIP
# 0             0        green   2491683    11.7      2.99    0.099
# 1             0       yellow  25108257    13.2      3.56    0.154
# 2             1        green   1920243    11.4      2.98    0.097
# 3             1       yellow  17740795    12.3      3.39    0.152
# 4             2        green   1405221    11.3      3.07    0.095
# 5             2       yellow  12608273    11.7      3.30    0.148
# 6             3        green   1096752    11.5      3.28    0.089
# 7             3       yellow   8966945    11.8      3.55    0.139
# 8             4        green    926996    12.1      3.70    0.074
# 9             4       yellow   6796280    12.6      4.45    0.121
# 10            5        green    663550    13.7      4.66    0.078
# 11            5       yellow   7064531    12.6      4.97    0.133
# 12            6        green    986060    15.7      4.72    0.086
# 13            6       yellow  15849525    12.1      3.79    0.143
# 14            7        green   1921570    15.8      3.65    0.090
# 15            7       yellow  27092977    13.2      3.09    0.156
# 16            8        green   2830291    15.8      3.25    0.097
# 17            8       yellow  33994149    14.4      2.79    0.160
# 18            9        green   3005987    15.1      3.24    0.095
# 19            9       yellow  35254789    14.6      2.73    0.157
# 20           10        green   2873449    14.8      3.23    0.085
# 21           10       yellow  35712668    14.8      2.79    0.152
# 22           11        green   2848851    14.9      3.22    0.081
# 23           11       yellow  37598396    15.1      2.79    0.150
# 24           12        green   2884149    14.9      3.20    0.080
# 25           12       yellow  39997833    15.4      2.84    0.149
# 26           13        green   2903829    15.0      3.16    0.078
# 27           13       yellow  40466809    15.8      3.00    0.149
# 28           14        green   3253525    15.6      3.08    0.077
# 29           14       yellow  42516559    16.8      3.13    0.148
# 30           15        green   3579840    16.0      3.00    0.079
# 31           15       yellow  42137927    17.2      3.11    0.149
# 32           16        green   3850351    16.2      2.95    0.086
# 33           16       yellow  39266555    17.3      3.17    0.161
# 34           17        green   4189228    15.3      2.75    0.094
# 35           17       yellow  44507630    16.5      2.96    0.165
# 36           18        green   4497373    13.8      2.64    0.102
# 37           18       yellow  49698998    15.0      2.76    0.169
# 38           19        green   4287283    12.6      2.64    0.105
# 39           19       yellow  47813213    13.9      2.82    0.170
# 40           20        green   3776608    12.4      2.74    0.102
# 41           20       yellow  43809428    13.6      3.07    0.167
# 42           21        green   3535508    12.2      2.87    0.103
# 43           21       yellow  43339607    13.6      3.21    0.167
# 44           22        green   3317678    12.3      3.02    0.105
# 45           22       yellow  40927906    13.8      3.34    0.164
# 46           23        green   3035748    12.1      3.04    0.103
# 47           23       yellow  33911960    13.8      3.54    0.158

# %%
sf_query("""
SELECT pickup_dow,
       is_weekend,
       service_type,
       COUNT(*) AS n,
       ROUND(AVG(trip_minutes),1) AS avg_min,
       ROUND(AVG(trip_distance),2) AS avg_dist,
       ROUND(AVG(tip_pct),3) AS avg_tip
FROM ANALYTICS.OBT_TRIPS_CLEAN_V
GROUP BY 1,2,3
ORDER BY 1,2,3;
""")
# Out:
#    PICKUP_DOW  IS_WEEKEND SERVICE_TYPE          N AVG_MIN  AVG_DIST  AVG_TIP
# 0         Fri       False        green   10577314    14.4      2.99    0.092
# 1         Fri       False       yellow  117861767    15.3      3.05    0.157
# 2         Mon       False        green    8089189    13.8      3.05    0.090
# 3         Mon       False       yellow   99224635    14.3      3.24    0.158
# 4         Sat        True        green   11208650    13.5      3.08    0.093
# 5         Sat        True       yellow  115251971    13.8      2.97    0.147
# 6         Sun        True        green    9378607    13.0      3.18    0.093
# 7         Sun        True       yellow   99407905    13.6      3.40    0.148
# 8         Thu       False        green    9507843    14.6      3.02    0.094
# 9         Thu       False       yellow  117380578    15.7      3.04    0.162
# 10        Tue       False        green    8424218    14.3      3.01    0.093
# 11        Tue       False       yellow  109142149    14.9      3.00    0.163
# 12        Wed       False        green    8895952    14.4      3.02    0.093
# 13        Wed       False       yellow  113913005    15.3      2.99    0.163
