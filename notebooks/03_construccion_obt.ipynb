# %%
import snowflake.connector
import os
import pandas as pd
from snowflake.connector.errors import NotSupportedError

def sf_query(sql: str):
    """
    Ejecuta UNA sola sentencia SQL en Snowflake.
    - Si trae resultados, devuelve un DataFrame.
    - Si no, imprime confirmación.
    Maneja SHOW/DESCRIBE/SELECT aunque fetch_pandas_all no esté soportado.
    """
    conn = snowflake.connector.connect(
        user=os.getenv("SNOWFLAKE_USER"),
        password=os.getenv("SNOWFLAKE_PASSWORD"),
        account=os.getenv("SNOWFLAKE_HOST").split(".snowflakecomputing.com")[0],
        warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
        database=os.getenv("SNOWFLAKE_DATABASE"),
        role=os.getenv("SNOWFLAKE_ROLE"),
    )
    try:
        cur = conn.cursor()
        # Intentamos usar Arrow para que fetch_pandas_all funcione
        try:
            cur.execute("ALTER SESSION SET QUERY_RESULT_FORMAT=ARROW")
        except Exception:
            pass  # si falla, igual seguimos (haremos fallback)

        cur.execute(sql)

        if cur.description:  # hay result set (SELECT/SHOW/DESCRIBE)
            try:
                df = cur.fetch_pandas_all()  # rápido si hay Arrow/pyarrow
            except NotSupportedError:
                # Fallback sin Arrow
                rows = cur.fetchall()
                cols = [d[0] for d in cur.description]
                df = pd.DataFrame(rows, columns=cols)
            finally:
                cur.close()
            return df
        else:
            cur.close()
            print("Executed successfully.")
    finally:
        conn.close()

# %%
sf_query("""
CREATE OR REPLACE VIEW ANALYTICS.OBT_TRIPS_V AS
SELECT
  service_type,
  pickup_datetime,
  dropoff_datetime,
  DATEDIFF('minute', pickup_datetime, dropoff_datetime)                         AS trip_minutes,
  EXTRACT(HOUR FROM pickup_datetime)                                            AS pickup_hour,
  TO_CHAR(pickup_datetime, 'DY')                                                AS pickup_dow,
  IFF(DAYOFWEEK(pickup_datetime) IN (0, 6), TRUE, FALSE)                        AS is_weekend,
  trip_distance,
  pu_location_id,
  do_location_id,
  fare_amount,
  tip_amount,
  tolls_amount,
  mta_tax,
  improvement_surcharge,
  congestion_surcharge,
  total_amount,
  payment_type,
  vendor_id,
  rate_code_id,
  store_and_fwd_flag,
  year,
  month,
  IFF(NULLIFZERO(fare_amount) IS NULL, NULL, tip_amount / NULLIFZERO(fare_amount)) AS tip_pct
FROM RAW.TRIPS_ALL;
""")
# Out:
#                                    status
# 0  View OBT_TRIPS_V successfully created.

# %%
sf_query("SHOW VIEWS IN SCHEMA ANALYTICS;")
# Out:
#                         created_on         name reserved database_name  \
# 0 2025-10-23 08:38:03.582000-07:00  OBT_TRIPS_V               DM_PSET3
#
#   schema_name     owner comment  \
# 0   ANALYTICS  SYSADMIN
#
#                                                 text is_secure  \
# 0  CREATE OR REPLACE VIEW ANALYTICS.OBT_TRIPS_V A...     false
#
#   is_materialized owner_role_type change_tracking
# 0           false            ROLE             OFF

# %%
sf_query("SELECT COUNT(*) AS cnt FROM ANALYTICS.OBT_TRIPS_V;")
# Out:
#          CNT
# 0  851622729

# %%
sf_query("SELECT COUNT(*) AS cnt FROM RAW.TRIPS_ALL;")
# Out:
#          CNT
# 0  851622729

# %%
sf_query("SELECT * FROM ANALYTICS.OBT_TRIPS_V LIMIT 20;")
# Out:
#    SERVICE_TYPE     PICKUP_DATETIME    DROPOFF_DATETIME  TRIP_MINUTES  \
# 0        yellow 2015-01-01 03:05:17 2015-01-01 03:33:46            28
# 1        yellow 2015-01-01 03:33:16 2015-01-01 03:35:16             2
# 2        yellow 2015-01-01 03:56:14 2015-01-01 04:04:54             8
# 3        yellow 2015-01-01 03:06:20 2015-01-01 03:13:19             7
# 4        yellow 2015-01-01 03:12:36 2015-01-01 03:22:41            10
# 5        yellow 2015-01-01 03:03:05 2015-01-01 03:18:23            15
# 6        yellow 2015-01-01 03:01:54 2015-01-01 03:07:06             6
# 7        yellow 2015-01-01 03:09:21 2015-01-01 03:26:29            17
# 8        yellow 2015-01-01 03:32:01 2015-01-01 03:36:17             4
# 9        yellow 2015-01-01 03:08:35 2015-01-01 03:20:12            12
# 10       yellow 2015-01-01 03:13:59 2015-01-01 03:35:47            22
# 11       yellow 2015-01-01 03:45:25 2015-01-01 03:49:51             4
# 12       yellow 2015-01-01 03:28:24 2015-01-01 03:44:23            16
# 13       yellow 2015-01-01 03:42:04 2015-01-01 04:09:36            27
# 14       yellow 2015-01-01 03:32:39 2015-01-01 03:59:05            27
# 15       yellow 2015-01-01 03:46:56 2015-01-01 03:58:53            12
# 16       yellow 2015-01-01 03:47:07 2015-01-01 04:09:53            22
# 17       yellow 2015-01-01 03:24:48 2015-01-01 04:16:03            52
# 18       yellow 2015-01-01 03:00:32 2015-01-01 03:12:41            12
# 19       yellow 2015-01-01 03:36:15 2015-01-01 03:59:19            23
#
#     PICKUP_HOUR PICKUP_DOW  IS_WEEKEND  TRIP_DISTANCE  PU_LOCATION_ID  \
# 0             3        Thu       False           7.10             166
# 1             3        Thu       False           0.50             107
# 2             3        Thu       False           4.26               7
# 3             3        Thu       False           1.27               7
# 4             3        Thu       False           3.90             161
# 5             3        Thu       False           4.06             263
# 6             3        Thu       False           0.95             229
# 7             3        Thu       False           5.20             264
# 8             3        Thu       False           0.64              41
# 9             3        Thu       False           2.00             238
# 10            3        Thu       False           5.10             229
# 11            3        Thu       False           1.56             162
# 12            3        Thu       False           3.30             186
# 13            3        Thu       False           5.70              45
# 14            3        Thu       False           4.54              79
# 15            3        Thu       False           1.80             261
# 16            3        Thu       False           3.60             142
# 17            3        Thu       False          23.89             107
# 18            3        Thu       False           1.60              50
# 19            3        Thu       False           5.94             209
#
#     DO_LOCATION_ID  ...  IMPROVEMENT_SURCHARGE  CONGESTION_SURCHARGE  \
# 0                7  ...                    0.0                   NaN
# 1              107  ...                    0.0                   NaN
# 2               70  ...                    0.3                   NaN
# 3              179  ...                    0.3                   NaN
# 4               41  ...                    0.0                   NaN
# 5               79  ...                    0.3                   NaN
# 6              163  ...                    0.3                   NaN
# 7              264  ...                    0.0                   NaN
# 8               41  ...                    0.3                   NaN
# 9               48  ...                    0.0                   NaN
# 10             129  ...                    0.0                   NaN
# 11             141  ...                    0.3                   NaN
# 12              87  ...                    0.0                   NaN
# 13             230  ...                    0.0                   NaN
# 14              48  ...                    0.3                   NaN
# 15             158  ...                    0.0                   NaN
# 16             137  ...                    0.0                   NaN
# 17             171  ...                    0.3                   NaN
# 18             162  ...                    0.0                   NaN
# 19              37  ...                    0.3                   NaN
#
#     TOTAL_AMOUNT  PAYMENT_TYPE  VENDOR_ID  RATE_CODE_ID  STORE_AND_FWD_FLAG  \
# 0          28.93             1          1             1                   N
# 1           6.80             1          1             1                   N
# 2          14.80             2          2             1                   N
# 3           7.80             2          2             1                   N
# 4          16.55             1          1             1                   N
# 5          18.20             1          2             1                   N
# 6           6.80             2          2             1                   N
# 7          18.50             2          1             1                   N
# 8           6.30             2          2             1                   N
# 9          14.65             1          1             1                   N
# 10         22.08             1          1             1                   N
# 11          9.20             1          2             1                   N
# 12         15.50             1          1             1                   N
# 13         23.80             2          1             1                   N
# 14         19.30             2          2             1                   N
# 15         12.50             1          1             1                   N
# 16         21.96             1          1             1                   N
# 17         80.60             1          2             1                   N
# 18         10.30             2          1             1                   N
# 19         27.20             1          2             1                   N
#
#     YEAR MONTH   TIP_PCT
# 0   2015     1  0.105200
# 1   2015     1  0.571429
# 2   2015     1  0.000000
# 3   2015     1  0.000000
# 4   2015     1  0.220000
# 5   2015     1  0.207143
# 6   2015     1  0.000000
# 7   2015     1  0.000000
# 8   2015     1  0.000000
# 9   2015     1  0.335000
# 10  2015     1  0.065641
# 11  2015     1  0.215385
# 12  2015     1  0.075758
# 13  2015     1  0.000000
# 14  2015     1  0.000000
# 15  2015     1  0.217391
# 16  2015     1  0.215294
# 17  2015     1  0.201515
# 18  2015     1  0.000000
# 19  2015     1  0.204651
#
# [20 rows x 24 columns]

# %%
sf_query("""
SELECT
  SUM(IFF(trip_minutes < 0, 1, 0)) AS trips_negativos,
  SUM(IFF(tip_pct < 0, 1, 0))      AS tips_negativos,
  SUM(IFF(tip_pct > 5, 1, 0))      AS tips_mayor_500pct
FROM ANALYTICS.OBT_TRIPS_V;
""")
# Out:
#    TRIPS_NEGATIVOS  TIPS_NEGATIVOS  TIPS_MAYOR_500PCT
# 0            13035           28116             123109
