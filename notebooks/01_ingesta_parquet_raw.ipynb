# %% [markdown]
# variables de entorno

# %%
import os

REQ = [
    "SNOWFLAKE_HOST","SNOWFLAKE_USER","SNOWFLAKE_PASSWORD",
    "SNOWFLAKE_DATABASE","SNOWFLAKE_SCHEMA_RAW","SNOWFLAKE_SCHEMA_ANALYTICS",
    "SNOWFLAKE_WAREHOUSE","SNOWFLAKE_ROLE"
]

missing = [k for k in REQ if not os.getenv(k)]
assert not missing, f"Faltan en .env: {missing} — complétalas y reintenta."

# Derivar SNOWFLAKE_ACCOUNT si no está definido (desde el host)
sf_account = os.getenv("SNOWFLAKE_ACCOUNT")
if not sf_account:
    host = os.getenv("SNOWFLAKE_HOST")  # p.ej. xpc24435.us-east-1.snowflakecomputing.com
    sf_account = host.replace(".snowflakecomputing.com", "")

DATA_ROOT = os.getenv("DATA_ROOT", "/home/jovyan/work/datasets")

print("OK .env cargado.")
print("  DATA_ROOT =", DATA_ROOT)
print("  ACCOUNT   =", sf_account)
print("  DB/RAW/AN =",
      os.getenv("SNOWFLAKE_DATABASE"), os.getenv("SNOWFLAKE_SCHEMA_RAW"), os.getenv("SNOWFLAKE_SCHEMA_ANALYTICS"))
print("  WH/ROLE   =",
      os.getenv("SNOWFLAKE_WAREHOUSE"), os.getenv("SNOWFLAKE_ROLE"))
# Out:
# OK .env cargado.
#   DATA_ROOT = /home/jovyan/work/datasets
#   ACCOUNT   = xpc24435.us-east-1
#   DB/RAW/AN = DM_PSET3 RAW ANALYTICS
#   WH/ROLE   = WH_DM SYSADMIN

# %%
from pyspark.sql import SparkSession

# Reinicia por si había sesiones previas colgadas
try:
    spark.stop()
except:
    pass

spark = SparkSession.builder.getOrCreate()

sfOptions = {
    "sfURL": os.getenv("SNOWFLAKE_HOST"),
    "sfUser": os.getenv("SNOWFLAKE_USER"),
    "sfPassword": os.getenv("SNOWFLAKE_PASSWORD"),
    "sfDatabase": os.getenv("SNOWFLAKE_DATABASE"),
    "sfSchema": os.getenv("SNOWFLAKE_SCHEMA_RAW"),
    "sfWarehouse": os.getenv("SNOWFLAKE_WAREHOUSE"),
    "sfRole": os.getenv("SNOWFLAKE_ROLE"),
    "sfAccount": os.getenv("SNOWFLAKE_HOST").replace(".snowflakecomputing.com",""),
}

print("Spark listo ✔️")
print("  RAW schema :", os.getenv("SNOWFLAKE_SCHEMA_RAW"))
print("  URL/Acct   :", os.getenv("SNOWFLAKE_HOST"), "|", sfOptions["sfAccount"])
# Out:
# Spark listo ✔️
#   RAW schema : RAW
#   URL/Acct   : xpc24435.us-east-1.snowflakecomputing.com | xpc24435.us-east-1

# %%
from pathlib import Path
from pyspark.sql.functions import col

def _normalize_timestamps(df):
    """
    Convierte columnas de fecha/hora típicas de TLC a 'timestamp' clásico,
    para que el conector Spark↔Snowflake las acepte sin error.
    """
    candidates = [
        "tpep_pickup_datetime", "tpep_dropoff_datetime",   # yellow
        "lpep_pickup_datetime", "lpep_dropoff_datetime",   # green
    ]
    for c in candidates:
        if c in df.columns:
            df = df.withColumn(c, col(c).cast("timestamp"))
    return df

def load_month(service: str, year: int, month: str, sample: int | None = None) -> bool:
    """
    Lee un parquet local (DATA_ROOT/<service>_tripdata_<YYYY>-<MM>.parquet)
    y lo escribe en Snowflake como RAW.TRIPS_<SERVICE>_<YYYY>_<MM>.
    - 'service' : 'yellow' o 'green'
    - 'month'   : '01'..'12' (dos dígitos)
    - sample    : si es int, limita filas para smoke test; si None, carga completa
    """
    fname = f"{service}_tripdata_{year}-{month}.parquet"
    src = Path(DATA_ROOT) / fname
    if not src.exists():
        print(f"⚠️ No existe: {src}")
        return False

    df = spark.read.parquet(str(src))
    if sample:
        df = df.limit(sample)

    df = _normalize_timestamps(df)

    target = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{service.upper()}_{year}_{month}'
    (df.write.format("snowflake")
       .options(**sfOptions)
       .option("dbtable", target)
       .mode("overwrite")
       .save())
    print("✅ Cargado:", target)
    return True

def sf_count(table: str) -> int:
    """
    Devuelve COUNT(*) de una tabla Snowflake dada como 'SCHEMA.TABLE'.
    """
    q = f"SELECT COUNT(*) AS c FROM {table}"
    df = (spark.read.format("snowflake")
          .options(**sfOptions)
          .option("query", q)
          .load())
    return int(df.collect()[0]["C"])

print("helpers listos ✔️")
# Out:
# helpers listos ✔️

# %%
from pathlib import Path

SERVICE = "yellow"
YEAR = 2015
MONTH = "01"
RAW = os.getenv("SNOWFLAKE_SCHEMA_RAW")
REAL_TABLE = f"{RAW}.TRIPS_{SERVICE.upper()}_{YEAR}_{MONTH}"

# 1)  conexión a Snowflake 
ping = (spark.read.format("snowflake")
        .options(**sfOptions)
        .option("query", "SELECT CURRENT_ACCOUNT() AS acct, CURRENT_WAREHOUSE() AS wh, CURRENT_ROLE() AS role, CURRENT_VERSION() AS ver")
        .load())
print("✅ Conexión Snowflake OK:")
ping.show(truncate=False)

# 2) Verificar que el parquet local existe 
src = Path(DATA_ROOT) / f"{SERVICE}_tripdata_{YEAR}-{MONTH}.parquet"
assert src.exists(), f"No existe el parquet local: {src}"
df_local = spark.read.parquet(str(src)).limit(1000)
print("✅ Lectura local OK (sample 1000):", df_local.count(), "filas")


try:
    cnt_real = sf_count(REAL_TABLE)
    print(f"✅ COUNT real en Snowflake ({REAL_TABLE}):", cnt_real)
except Exception as e:
    print(f"⚠️ No se pudo contar {REAL_TABLE} (quizá no existe aún):", e)
# Out:
# ✅ Conexión Snowflake OK:
# +--------+-----+--------+------+
# |ACCT    |WH   |ROLE    |VER   |
# +--------+-----+--------+------+
# |XPC24435|WH_DM|SYSADMIN|9.32.1|
# +--------+-----+--------+------+
#
# ✅ Lectura local OK (sample 1000): 1000 filas
# ✅ COUNT real en Snowflake (RAW.TRIPS_YELLOW_2015_01): 1000

# %%
# CELDA 5 — Plan: sobrescribir YELLOW 2015-01 completo (sin sample)

SERVICES = ["yellow"]
YEARS = [2015]
MONTHS = ["01"]

print("Plan:", SERVICES, YEARS, MONTHS, "→ overwrite completo")
# Out:
# Plan: ['yellow'] [2015] ['01'] → overwrite completo

# %%
# CELDA 6 — Ejecutar la carga (según el plan de la celda 5)

for svc in SERVICES:
    for y in YEARS:
        for m in MONTHS:
            try:
                ok = load_month(svc, y, m)   # carga completa (sin sample)
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_YELLOW_2015_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2015_01  |  COUNT = 12741035

# %%
SERVICES = ["yellow"]
YEARS = [2017]
MONTHS = ["09","10","11","12"]
print("Plan:", SERVICES, YEARS, MONTHS)
# Out:
# Plan: ['yellow'] [2017] ['09', '10', '11', '12']

# %%
# CELDA 6 — Ejecutar la carga según el plan

for svc in SERVICES:
    for y in YEARS:
        for m in MONTHS:
            try:
                ok = load_month(svc, y, m)   # carga completa (sin sample)
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_09  |  COUNT = 8945421
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_10  |  COUNT = 9768672
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_11  |  COUNT = 9284803
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2017_12  |  COUNT = 9508501

# %%
SERVICES = ["yellow"]
YEARS = [2018]
MONTHS = [f"{m:02d}" for m in range(1,13)]
print("Plan:", SERVICES, YEARS, MONTHS)
# Out:
# Plan: ['yellow'] [2018] ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
# CELDA 6 — Ejecutar la carga según el plan
for svc in SERVICES:
    for y in YEARS:
        for m in MONTHS:
            try:
                ok = load_month(svc, y, m)
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_01  |  COUNT = 8760687
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_02  |  COUNT = 8492819
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_03  |  COUNT = 9431289
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_04  |  COUNT = 9306216
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_05  |  COUNT = 9224788
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_06
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_06  |  COUNT = 8714667
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_07
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_07  |  COUNT = 7851143
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_08
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_08  |  COUNT = 7855040
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_09  |  COUNT = 8049094
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_10  |  COUNT = 8834520
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_11  |  COUNT = 8155449
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2018_12  |  COUNT = 8195675

# %%
# CELDA 5 — Plan del bloque (YELLOW 2019-02..12)
SERVICES = ["yellow"]
YEARS = [2019]
MONTHS = [f"{m:02d}" for m in range(2,13)]  # 02..12
print("Plan:", SERVICES, YEARS, MONTHS)
# Out:
# Plan: ['yellow'] [2019] ['02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
# CELDA 6 — Ejecutar la carga según el plan
for svc in SERVICES:
    for y in YEARS:
        for m in MONTHS:
            try:
                ok = load_month(svc, y, m)
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_02  |  COUNT = 7049370
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_03  |  COUNT = 7866620
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_04  |  COUNT = 7475949
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_05  |  COUNT = 7598445
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_06
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_06  |  COUNT = 6971560
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_07
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_07  |  COUNT = 6310419
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_08
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_08  |  COUNT = 6073357
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_09  |  COUNT = 6567788
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_10  |  COUNT = 7213891
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_11  |  COUNT = 6878111
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2019_12  |  COUNT = 6896317

# %%
# CELDA 5 — Plan YELLOW 2020→2025 con 2025 limitado a 01–08

SERVICES = ["yellow"]
YEARS = list(range(2023, 2026))  # 2020..2025

MONTHS_2020_2024 = [f"{m:02d}" for m in range(1,13)]
MONTHS_2023 = [f"{m:02d}" for m in range(6,13)]# 01..12
MONTHS_2025 = [f"{m:02d}" for m in range(1,9)]        # 01..08

print("Plan YELLOW:")
print("  Años:", YEARS)
print("  Meses 2020–2024:", MONTHS_2020_2024)
print("  Meses 2025:", MONTHS_2025)
# Out:
# Plan YELLOW:
#   Años: [2020, 2021, 2022, 2023, 2024, 2025]
#   Meses 2020–2024: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   Meses 2025: ['01', '02', '03', '04', '05', '06', '07', '08']

# %%
# CELDA 6 — Ejecutar carga YELLOW 2020→2025 (2025 solo 01–08)

for svc in SERVICES:
    for y in YEARS:
        months = MONTHS_2025 if y == 2025 else MONTHS_2020_2024
        for m in months:
            try:
                ok = load_month(svc, y, m)
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_01  |  COUNT = 6405008
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_02  |  COUNT = 6299367
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_03  |  COUNT = 3007687
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_04  |  COUNT = 238073
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_05  |  COUNT = 348415
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_06
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_06  |  COUNT = 549797
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_07
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_07  |  COUNT = 800412
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_08
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_08  |  COUNT = 1007286
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_09  |  COUNT = 1341017
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_10  |  COUNT = 1681132
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_11  |  COUNT = 1509000
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2020_12  |  COUNT = 1461898
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_01  |  COUNT = 1369769
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_02  |  COUNT = 1371709
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_03  |  COUNT = 1925152
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_04  |  COUNT = 2171187
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_05  |  COUNT = 2507109
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_06
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_06  |  COUNT = 2834264
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_07
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_07  |  COUNT = 2821746
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_08
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_08  |  COUNT = 2788757
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_09  |  COUNT = 2963793
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_10  |  COUNT = 3463504
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_11  |  COUNT = 3472949
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2021_12  |  COUNT = 3214369
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_01  |  COUNT = 2463931
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_02  |  COUNT = 2979431
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_03  |  COUNT = 3627882
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_04  |  COUNT = 3599920
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_05  |  COUNT = 3588295
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_06
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_06  |  COUNT = 3558124
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_07
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_07  |  COUNT = 3174394
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_08
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_08  |  COUNT = 3152677
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_09
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_09  |  COUNT = 3183767
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_10
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_10  |  COUNT = 3675411
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_11
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_11  |  COUNT = 3252717
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_12
# ✅ Cargado: RAW.TRIPS_YELLOW_2022_12  |  COUNT = 3399549
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_01
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_01  |  COUNT = 3066766
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_02
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_02  |  COUNT = 2913955
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_03
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_03  |  COUNT = 3403766
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_04
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_04  |  COUNT = 3288250
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_05
# ✅ Cargado: RAW.TRIPS_YELLOW_2023_05  |  COUNT = 3513649

# %%
# CELDA 2.5 — Reinicio rápido de Spark y ping a Snowflake (no escribe)

try:
    spark.stop()
except:
    pass

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

def sf_ping():
    df = (spark.read.format("snowflake")
          .options(**sfOptions)
          .option("query", "SELECT CURRENT_ACCOUNT() acct, CURRENT_WAREHOUSE() wh, CURRENT_ROLE() role, CURRENT_TIMESTAMP() ts")
          .load())
    df.show(truncate=False)

print("🔄 Spark reiniciado. Ping a Snowflake:")
sf_ping()
# Out:
# 🔄 Spark reiniciado. Ping a Snowflake:
# +--------+-----+--------+-----------------------+
# |ACCT    |WH   |ROLE    |TS                     |
# +--------+-----+--------+-----------------------+
# |XPC24435|WH_DM|SYSADMIN|2025-10-22 04:32:20.757|
# +--------+-----+--------+-----------------------+

# %%
# CELDA 5 — Plan dinámico (YELLOW 2020→2025 con 2025-01..08), solo faltantes

from itertools import product

# universo esperado
years_all = list(range(2020, 2026))
months_full = [f"{m:02d}" for m in range(1,13)]
months_2025 = [f"{m:02d}" for m in range(1,9)]  # 01..08
expected = {(y, m) for y in years_all for m in (months_2025 if y==2025 else months_full)}

# ya cargado en RAW
q_loaded = (
    "WITH t AS ("
    " SELECT table_name,"
    " TRY_TO_NUMBER(REGEXP_SUBSTR(table_name, 'TRIPS_YELLOW_(\\\\d{4})_', 1, 1, 'e', 1)) AS yr,"
    " TRY_TO_NUMBER(REGEXP_SUBSTR(table_name, 'TRIPS_YELLOW_\\\\d{4}_(\\\\d{2})', 1, 1, 'e', 1)) AS mo"
    " FROM INFORMATION_SCHEMA.TABLES"
    " WHERE table_schema='RAW' AND table_name ILIKE 'TRIPS_YELLOW_%'"
    ") SELECT yr, mo FROM t WHERE yr IS NOT NULL AND mo IS NOT NULL"
)
df_loaded = (spark.read.format("snowflake")
             .options(**sfOptions)
             .option("query", q_loaded)
             .load())

loaded = {(int(r["YR"]), f"{int(r['MO']):02d}") for r in df_loaded.collect() if r["YR"] is not None and r["MO"] is not None}

missing = sorted([(y, m) for (y, m) in expected if (y, m) not in loaded])

# Armamos listas para el bucle
SERVICES = ["yellow"]
YEARS = sorted(list({y for y, _ in missing}))
MONTHS_BY_YEAR = {y: [m for (yy, m) in missing if yy == y] for y in YEARS}

print("📋 Faltantes YELLOW (cuenta):", len(missing))
for y in YEARS:
    print(f"  {y}: {MONTHS_BY_YEAR[y]}")
# Out:
# 📋 Faltantes YELLOW (cuenta): 0

# %%
# CELDA 5 — Plan dinámico (GREEN 2015→2025 con 2025-01..08), solo faltantes

# universo esperado
years_all_g = list(range(2015, 2026))                      # 2015..2025
months_full  = [f"{m:02d}" for m in range(1,13)]           # 01..12
months_2025g = [f"{m:02d}" for m in range(1,9)]            # 01..08

expected_g = {(y, m) for y in years_all_g for m in (months_2025g if y==2025 else months_full)}

# ya cargado en RAW para GREEN
q_loaded_g = (
    "WITH t AS ("
    " SELECT table_name,"
    " TRY_TO_NUMBER(REGEXP_SUBSTR(table_name, 'TRIPS_GREEN_(\\\\d{4})_', 1, 1, 'e', 1)) AS yr,"
    " TRY_TO_NUMBER(REGEXP_SUBSTR(table_name, 'TRIPS_GREEN_\\\\d{4}_(\\\\d{2})', 1, 1, 'e', 1)) AS mo"
    " FROM INFORMATION_SCHEMA.TABLES"
    " WHERE table_schema='RAW' AND table_name ILIKE 'TRIPS_GREEN_%'"
    ") SELECT yr, mo FROM t WHERE yr IS NOT NULL AND mo IS NOT NULL"
)

df_loaded_g = (spark.read.format("snowflake")
               .options(**sfOptions)
               .option("query", q_loaded_g)
               .load())

loaded_g = {(int(r["YR"]), f"{int(r['MO']):02d}") for r in df_loaded_g.collect() if r["YR"] is not None and r["MO"] is not None}
missing_g = sorted([(y, m) for (y, m) in expected_g if (y, m) not in loaded_g])

# Armamos listas para el bucle
SERVICES = ["green"]
YEARS = sorted(list({y for y, _ in missing_g}))
MONTHS_BY_YEAR = {y: [m for (yy, m) in missing_g if yy == y] for y in YEARS}

print("📋 Faltantes GREEN (cuenta):", len(missing_g))
for y in YEARS:
    print(f"  {y}: {MONTHS_BY_YEAR[y]}")
# Out:
# 📋 Faltantes GREEN (cuenta): 127
#   2015: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2016: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2017: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2018: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2019: ['02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2020: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2021: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2022: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2023: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2024: ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
#   2025: ['01', '02', '03', '04', '05', '06', '07', '08']

# %%
SERVICES = ["green"]
YEARS = [2015]
MONTHS = [f"{m:02d}" for m in range(1,13)]  # 01..12
print("Plan:", SERVICES, YEARS, MONTHS)
# Out:
# Plan: ['green'] [2015] ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
# CELDA 6 — Ejecutar la carga según el plan actual

for svc in SERVICES:
    for y in YEARS:
        for m in MONTHS:
            try:
                ok = load_month(svc, y, m)  # normaliza lpep_* datetime dentro
                if ok:
                    table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_{svc.upper()}_{y}_{m}'
                    c = sf_count(table)
                    print(f"✅ Cargado: {table}  |  COUNT = {c}")
            except Exception as e:
                print(f"❌ Error en {svc} {y}-{m}:", e)
# Out:
# ✅ Cargado: RAW.TRIPS_GREEN_2015_01
# ✅ Cargado: RAW.TRIPS_GREEN_2015_01  |  COUNT = 1508493
# ✅ Cargado: RAW.TRIPS_GREEN_2015_02
# ✅ Cargado: RAW.TRIPS_GREEN_2015_02  |  COUNT = 1574830
# ✅ Cargado: RAW.TRIPS_GREEN_2015_03
# ✅ Cargado: RAW.TRIPS_GREEN_2015_03  |  COUNT = 1722574
# ✅ Cargado: RAW.TRIPS_GREEN_2015_04
# ✅ Cargado: RAW.TRIPS_GREEN_2015_04  |  COUNT = 1664394
# ✅ Cargado: RAW.TRIPS_GREEN_2015_05
# ✅ Cargado: RAW.TRIPS_GREEN_2015_05  |  COUNT = 1786848
# ✅ Cargado: RAW.TRIPS_GREEN_2015_06
# ✅ Cargado: RAW.TRIPS_GREEN_2015_06  |  COUNT = 1638868
# ✅ Cargado: RAW.TRIPS_GREEN_2015_07
# ✅ Cargado: RAW.TRIPS_GREEN_2015_07  |  COUNT = 1541671
# ✅ Cargado: RAW.TRIPS_GREEN_2015_08
# ✅ Cargado: RAW.TRIPS_GREEN_2015_08  |  COUNT = 1532343
# ✅ Cargado: RAW.TRIPS_GREEN_2015_09
# ✅ Cargado: RAW.TRIPS_GREEN_2015_09  |  COUNT = 1494927
# ✅ Cargado: RAW.TRIPS_GREEN_2015_10
# ✅ Cargado: RAW.TRIPS_GREEN_2015_10  |  COUNT = 1630536
# ✅ Cargado: RAW.TRIPS_GREEN_2015_11
# ✅ Cargado: RAW.TRIPS_GREEN_2015_11  |  COUNT = 1529984
# ✅ Cargado: RAW.TRIPS_GREEN_2015_12
# ✅ Cargado: RAW.TRIPS_GREEN_2015_12  |  COUNT = 1608297

# %%
# CELDA FINAL — Cargar todo lo que falta de GREEN (2016→2025-08)

years_green = {
    2016: [f"{m:02d}" for m in range(1,13)],
    2017: [f"{m:02d}" for m in range(1,13)],
    2018: [f"{m:02d}" for m in range(1,13)],
    2019: [f"{m:02d}" for m in range(2,13)],
    2020: [f"{m:02d}" for m in range(1,13)],
    2021: [f"{m:02d}" for m in range(1,13)],
    2022: [f"{m:02d}" for m in range(1,13)],
    2023: [f"{m:02d}" for m in range(1,13)],
    2024: [f"{m:02d}" for m in range(1,13)],
    2025: [f"{m:02d}" for m in range(1,9)],
}

errores = []
for y, months in years_green.items():
    for m in months:
        try:
            ok = load_month("green", y, m)
            if ok:
                table = f'{os.getenv("SNOWFLAKE_SCHEMA_RAW")}.TRIPS_GREEN_{y}_{m}'
                c = sf_count(table)
                print(f"✅ Cargado: {table}  |  COUNT = {c}")
        except Exception as e:
            msg = f"{y}-{m}: {e}"
            errores.append(msg)
            print(f"❌ Error en GREEN {msg}")

print("\nResumen:")
print("  Meses con error:", len(errores))
for e in errores:
    print("   -", e)
# Out:
# ✅ Cargado: RAW.TRIPS_GREEN_2016_01
# ✅ Cargado: RAW.TRIPS_GREEN_2016_01  |  COUNT = 1445292
# ✅ Cargado: RAW.TRIPS_GREEN_2016_02
# ✅ Cargado: RAW.TRIPS_GREEN_2016_02  |  COUNT = 1510722
# ✅ Cargado: RAW.TRIPS_GREEN_2016_03
# ✅ Cargado: RAW.TRIPS_GREEN_2016_03  |  COUNT = 1576393
# ✅ Cargado: RAW.TRIPS_GREEN_2016_04
# ✅ Cargado: RAW.TRIPS_GREEN_2016_04  |  COUNT = 1543926
# ✅ Cargado: RAW.TRIPS_GREEN_2016_05
# ✅ Cargado: RAW.TRIPS_GREEN_2016_05  |  COUNT = 1536979
# ✅ Cargado: RAW.TRIPS_GREEN_2016_06
# ✅ Cargado: RAW.TRIPS_GREEN_2016_06  |  COUNT = 1404727
# ✅ Cargado: RAW.TRIPS_GREEN_2016_07
# ✅ Cargado: RAW.TRIPS_GREEN_2016_07  |  COUNT = 1332510
# ✅ Cargado: RAW.TRIPS_GREEN_2016_08
# ✅ Cargado: RAW.TRIPS_GREEN_2016_08  |  COUNT = 1247675
# ✅ Cargado: RAW.TRIPS_GREEN_2016_09
# ✅ Cargado: RAW.TRIPS_GREEN_2016_09  |  COUNT = 1162373
# ✅ Cargado: RAW.TRIPS_GREEN_2016_10
# ✅ Cargado: RAW.TRIPS_GREEN_2016_10  |  COUNT = 1252572
# ✅ Cargado: RAW.TRIPS_GREEN_2016_11
# ✅ Cargado: RAW.TRIPS_GREEN_2016_11  |  COUNT = 1148214
# ✅ Cargado: RAW.TRIPS_GREEN_2016_12
# ✅ Cargado: RAW.TRIPS_GREEN_2016_12  |  COUNT = 1224158
# ✅ Cargado: RAW.TRIPS_GREEN_2017_01
# ✅ Cargado: RAW.TRIPS_GREEN_2017_01  |  COUNT = 1069565
# ✅ Cargado: RAW.TRIPS_GREEN_2017_02
# ✅ Cargado: RAW.TRIPS_GREEN_2017_02  |  COUNT = 1022313
# ✅ Cargado: RAW.TRIPS_GREEN_2017_03
# ✅ Cargado: RAW.TRIPS_GREEN_2017_03  |  COUNT = 1157827
# ✅ Cargado: RAW.TRIPS_GREEN_2017_04
# ✅ Cargado: RAW.TRIPS_GREEN_2017_04  |  COUNT = 1080844
# ✅ Cargado: RAW.TRIPS_GREEN_2017_05
# ✅ Cargado: RAW.TRIPS_GREEN_2017_05  |  COUNT = 1059463
# ✅ Cargado: RAW.TRIPS_GREEN_2017_06
# ✅ Cargado: RAW.TRIPS_GREEN_2017_06  |  COUNT = 976467
# ✅ Cargado: RAW.TRIPS_GREEN_2017_07
# ✅ Cargado: RAW.TRIPS_GREEN_2017_07  |  COUNT = 914783
# ✅ Cargado: RAW.TRIPS_GREEN_2017_08
# ✅ Cargado: RAW.TRIPS_GREEN_2017_08  |  COUNT = 867407
# ✅ Cargado: RAW.TRIPS_GREEN_2017_09
# ✅ Cargado: RAW.TRIPS_GREEN_2017_09  |  COUNT = 882464
# ✅ Cargado: RAW.TRIPS_GREEN_2017_10
# ✅ Cargado: RAW.TRIPS_GREEN_2017_10  |  COUNT = 925737
# ✅ Cargado: RAW.TRIPS_GREEN_2017_11
# ✅ Cargado: RAW.TRIPS_GREEN_2017_11  |  COUNT = 874173
# ✅ Cargado: RAW.TRIPS_GREEN_2017_12
# ✅ Cargado: RAW.TRIPS_GREEN_2017_12  |  COUNT = 906016
# ✅ Cargado: RAW.TRIPS_GREEN_2018_01
# ✅ Cargado: RAW.TRIPS_GREEN_2018_01  |  COUNT = 792744
# ✅ Cargado: RAW.TRIPS_GREEN_2018_02
# ✅ Cargado: RAW.TRIPS_GREEN_2018_02  |  COUNT = 769197
# ✅ Cargado: RAW.TRIPS_GREEN_2018_03
# ✅ Cargado: RAW.TRIPS_GREEN_2018_03  |  COUNT = 836246
# ✅ Cargado: RAW.TRIPS_GREEN_2018_04
# ✅ Cargado: RAW.TRIPS_GREEN_2018_04  |  COUNT = 799383
# ✅ Cargado: RAW.TRIPS_GREEN_2018_05
# ✅ Cargado: RAW.TRIPS_GREEN_2018_05  |  COUNT = 796552
# ✅ Cargado: RAW.TRIPS_GREEN_2018_06
# ✅ Cargado: RAW.TRIPS_GREEN_2018_06  |  COUNT = 738546
# ✅ Cargado: RAW.TRIPS_GREEN_2018_07
# ✅ Cargado: RAW.TRIPS_GREEN_2018_07  |  COUNT = 684374
# ✅ Cargado: RAW.TRIPS_GREEN_2018_08
# ✅ Cargado: RAW.TRIPS_GREEN_2018_08  |  COUNT = 675815
# ✅ Cargado: RAW.TRIPS_GREEN_2018_09
# ✅ Cargado: RAW.TRIPS_GREEN_2018_09  |  COUNT = 682032
# ✅ Cargado: RAW.TRIPS_GREEN_2018_10
# ✅ Cargado: RAW.TRIPS_GREEN_2018_10  |  COUNT = 731888
# ✅ Cargado: RAW.TRIPS_GREEN_2018_11
# ✅ Cargado: RAW.TRIPS_GREEN_2018_11  |  COUNT = 673287
# ✅ Cargado: RAW.TRIPS_GREEN_2018_12
# ✅ Cargado: RAW.TRIPS_GREEN_2018_12  |  COUNT = 719654
# ✅ Cargado: RAW.TRIPS_GREEN_2019_02
# ✅ Cargado: RAW.TRIPS_GREEN_2019_02  |  COUNT = 615594
# ✅ Cargado: RAW.TRIPS_GREEN_2019_03
# ✅ Cargado: RAW.TRIPS_GREEN_2019_03  |  COUNT = 643063
# ✅ Cargado: RAW.TRIPS_GREEN_2019_04
# ✅ Cargado: RAW.TRIPS_GREEN_2019_04  |  COUNT = 567852
# ✅ Cargado: RAW.TRIPS_GREEN_2019_05
# ✅ Cargado: RAW.TRIPS_GREEN_2019_05  |  COUNT = 545452
# ✅ Cargado: RAW.TRIPS_GREEN_2019_06
# ✅ Cargado: RAW.TRIPS_GREEN_2019_06  |  COUNT = 506238
# ✅ Cargado: RAW.TRIPS_GREEN_2019_07
# ✅ Cargado: RAW.TRIPS_GREEN_2019_07  |  COUNT = 470743
# ✅ Cargado: RAW.TRIPS_GREEN_2019_08
# ✅ Cargado: RAW.TRIPS_GREEN_2019_08  |  COUNT = 449695
# ✅ Cargado: RAW.TRIPS_GREEN_2019_09
# ✅ Cargado: RAW.TRIPS_GREEN_2019_09  |  COUNT = 449063
# ✅ Cargado: RAW.TRIPS_GREEN_2019_10
# ✅ Cargado: RAW.TRIPS_GREEN_2019_10  |  COUNT = 476386
# ✅ Cargado: RAW.TRIPS_GREEN_2019_11
# ✅ Cargado: RAW.TRIPS_GREEN_2019_11  |  COUNT = 449500
# ✅ Cargado: RAW.TRIPS_GREEN_2019_12
# ✅ Cargado: RAW.TRIPS_GREEN_2019_12  |  COUNT = 455294
# ✅ Cargado: RAW.TRIPS_GREEN_2020_01
# ✅ Cargado: RAW.TRIPS_GREEN_2020_01  |  COUNT = 447770
# ✅ Cargado: RAW.TRIPS_GREEN_2020_02
# ✅ Cargado: RAW.TRIPS_GREEN_2020_02  |  COUNT = 398632
# ✅ Cargado: RAW.TRIPS_GREEN_2020_03
# ✅ Cargado: RAW.TRIPS_GREEN_2020_03  |  COUNT = 223496
# ✅ Cargado: RAW.TRIPS_GREEN_2020_04
# ✅ Cargado: RAW.TRIPS_GREEN_2020_04  |  COUNT = 35644
# ✅ Cargado: RAW.TRIPS_GREEN_2020_05
# ✅ Cargado: RAW.TRIPS_GREEN_2020_05  |  COUNT = 57361
# ✅ Cargado: RAW.TRIPS_GREEN_2020_06
# ✅ Cargado: RAW.TRIPS_GREEN_2020_06  |  COUNT = 63110
# ✅ Cargado: RAW.TRIPS_GREEN_2020_07
# ✅ Cargado: RAW.TRIPS_GREEN_2020_07  |  COUNT = 72258
# ✅ Cargado: RAW.TRIPS_GREEN_2020_08
# ✅ Cargado: RAW.TRIPS_GREEN_2020_08  |  COUNT = 81063
# ✅ Cargado: RAW.TRIPS_GREEN_2020_09
# ✅ Cargado: RAW.TRIPS_GREEN_2020_09  |  COUNT = 87987
# ✅ Cargado: RAW.TRIPS_GREEN_2020_10
# ✅ Cargado: RAW.TRIPS_GREEN_2020_10  |  COUNT = 95120
# ✅ Cargado: RAW.TRIPS_GREEN_2020_11
# ✅ Cargado: RAW.TRIPS_GREEN_2020_11  |  COUNT = 88605
# ✅ Cargado: RAW.TRIPS_GREEN_2020_12
# ✅ Cargado: RAW.TRIPS_GREEN_2020_12  |  COUNT = 83130
# ✅ Cargado: RAW.TRIPS_GREEN_2021_01
# ✅ Cargado: RAW.TRIPS_GREEN_2021_01  |  COUNT = 76518
# ✅ Cargado: RAW.TRIPS_GREEN_2021_02
# ✅ Cargado: RAW.TRIPS_GREEN_2021_02  |  COUNT = 64572
# ✅ Cargado: RAW.TRIPS_GREEN_2021_03
# ✅ Cargado: RAW.TRIPS_GREEN_2021_03  |  COUNT = 83827
# ✅ Cargado: RAW.TRIPS_GREEN_2021_04
# ✅ Cargado: RAW.TRIPS_GREEN_2021_04  |  COUNT = 86941
# ✅ Cargado: RAW.TRIPS_GREEN_2021_05
# ✅ Cargado: RAW.TRIPS_GREEN_2021_05  |  COUNT = 88180
# ✅ Cargado: RAW.TRIPS_GREEN_2021_06
# ✅ Cargado: RAW.TRIPS_GREEN_2021_06  |  COUNT = 86737
# ✅ Cargado: RAW.TRIPS_GREEN_2021_07
# ✅ Cargado: RAW.TRIPS_GREEN_2021_07  |  COUNT = 83691
# ✅ Cargado: RAW.TRIPS_GREEN_2021_08
# ✅ Cargado: RAW.TRIPS_GREEN_2021_08  |  COUNT = 83499
# ✅ Cargado: RAW.TRIPS_GREEN_2021_09
# ✅ Cargado: RAW.TRIPS_GREEN_2021_09  |  COUNT = 95709
# ✅ Cargado: RAW.TRIPS_GREEN_2021_10
# ✅ Cargado: RAW.TRIPS_GREEN_2021_10  |  COUNT = 110891
# ✅ Cargado: RAW.TRIPS_GREEN_2021_11
# ✅ Cargado: RAW.TRIPS_GREEN_2021_11  |  COUNT = 108229
# ✅ Cargado: RAW.TRIPS_GREEN_2021_12
# ✅ Cargado: RAW.TRIPS_GREEN_2021_12  |  COUNT = 99961
# ✅ Cargado: RAW.TRIPS_GREEN_2022_01
# ✅ Cargado: RAW.TRIPS_GREEN_2022_01  |  COUNT = 62495
# ✅ Cargado: RAW.TRIPS_GREEN_2022_02
# ✅ Cargado: RAW.TRIPS_GREEN_2022_02  |  COUNT = 69399
# ✅ Cargado: RAW.TRIPS_GREEN_2022_03
# ✅ Cargado: RAW.TRIPS_GREEN_2022_03  |  COUNT = 78537
# ✅ Cargado: RAW.TRIPS_GREEN_2022_04
# ✅ Cargado: RAW.TRIPS_GREEN_2022_04  |  COUNT = 76136
# ✅ Cargado: RAW.TRIPS_GREEN_2022_05
# ✅ Cargado: RAW.TRIPS_GREEN_2022_05  |  COUNT = 76891
# ✅ Cargado: RAW.TRIPS_GREEN_2022_06
# ✅ Cargado: RAW.TRIPS_GREEN_2022_06  |  COUNT = 73718
# ✅ Cargado: RAW.TRIPS_GREEN_2022_07
# ✅ Cargado: RAW.TRIPS_GREEN_2022_07  |  COUNT = 64192
# ✅ Cargado: RAW.TRIPS_GREEN_2022_08
# ✅ Cargado: RAW.TRIPS_GREEN_2022_08  |  COUNT = 65929
# ✅ Cargado: RAW.TRIPS_GREEN_2022_09
# ✅ Cargado: RAW.TRIPS_GREEN_2022_09  |  COUNT = 69031
# ✅ Cargado: RAW.TRIPS_GREEN_2022_10
# ✅ Cargado: RAW.TRIPS_GREEN_2022_10  |  COUNT = 69322
# ✅ Cargado: RAW.TRIPS_GREEN_2022_11
# ✅ Cargado: RAW.TRIPS_GREEN_2022_11  |  COUNT = 62313
# ✅ Cargado: RAW.TRIPS_GREEN_2022_12
# ✅ Cargado: RAW.TRIPS_GREEN_2022_12  |  COUNT = 72439
# ✅ Cargado: RAW.TRIPS_GREEN_2023_01
# ✅ Cargado: RAW.TRIPS_GREEN_2023_01  |  COUNT = 68211
# ✅ Cargado: RAW.TRIPS_GREEN_2023_02
# ✅ Cargado: RAW.TRIPS_GREEN_2023_02  |  COUNT = 64809
# ✅ Cargado: RAW.TRIPS_GREEN_2023_03
# ✅ Cargado: RAW.TRIPS_GREEN_2023_03  |  COUNT = 72044
# ✅ Cargado: RAW.TRIPS_GREEN_2023_04
# ✅ Cargado: RAW.TRIPS_GREEN_2023_04  |  COUNT = 65392
# ✅ Cargado: RAW.TRIPS_GREEN_2023_05
# ✅ Cargado: RAW.TRIPS_GREEN_2023_05  |  COUNT = 69174
# ✅ Cargado: RAW.TRIPS_GREEN_2023_06
# ✅ Cargado: RAW.TRIPS_GREEN_2023_06  |  COUNT = 65550
# ✅ Cargado: RAW.TRIPS_GREEN_2023_07
# ✅ Cargado: RAW.TRIPS_GREEN_2023_07  |  COUNT = 61343
# ✅ Cargado: RAW.TRIPS_GREEN_2023_08
# ✅ Cargado: RAW.TRIPS_GREEN_2023_08  |  COUNT = 60649
# ✅ Cargado: RAW.TRIPS_GREEN_2023_09
# ✅ Cargado: RAW.TRIPS_GREEN_2023_09  |  COUNT = 65471
# ✅ Cargado: RAW.TRIPS_GREEN_2023_10
# ✅ Cargado: RAW.TRIPS_GREEN_2023_10  |  COUNT = 66177
# ✅ Cargado: RAW.TRIPS_GREEN_2023_11
# ✅ Cargado: RAW.TRIPS_GREEN_2023_11  |  COUNT = 64025
# ✅ Cargado: RAW.TRIPS_GREEN_2023_12
# ✅ Cargado: RAW.TRIPS_GREEN_2023_12  |  COUNT = 64215
# ✅ Cargado: RAW.TRIPS_GREEN_2024_01
# ✅ Cargado: RAW.TRIPS_GREEN_2024_01  |  COUNT = 56551
# ✅ Cargado: RAW.TRIPS_GREEN_2024_02
# ✅ Cargado: RAW.TRIPS_GREEN_2024_02  |  COUNT = 53577
# ✅ Cargado: RAW.TRIPS_GREEN_2024_03
# ✅ Cargado: RAW.TRIPS_GREEN_2024_03  |  COUNT = 57457
# ✅ Cargado: RAW.TRIPS_GREEN_2024_04
# ✅ Cargado: RAW.TRIPS_GREEN_2024_04  |  COUNT = 56471
# ✅ Cargado: RAW.TRIPS_GREEN_2024_05
# ✅ Cargado: RAW.TRIPS_GREEN_2024_05  |  COUNT = 61003
# ✅ Cargado: RAW.TRIPS_GREEN_2024_06
# ✅ Cargado: RAW.TRIPS_GREEN_2024_06  |  COUNT = 54748
# ✅ Cargado: RAW.TRIPS_GREEN_2024_07
# ✅ Cargado: RAW.TRIPS_GREEN_2024_07  |  COUNT = 51837
# ✅ Cargado: RAW.TRIPS_GREEN_2024_08
# ✅ Cargado: RAW.TRIPS_GREEN_2024_08  |  COUNT = 51771
# ✅ Cargado: RAW.TRIPS_GREEN_2024_09
# ✅ Cargado: RAW.TRIPS_GREEN_2024_09  |  COUNT = 54440
# ✅ Cargado: RAW.TRIPS_GREEN_2024_10
# ✅ Cargado: RAW.TRIPS_GREEN_2024_10  |  COUNT = 56147
# ✅ Cargado: RAW.TRIPS_GREEN_2024_11
# ✅ Cargado: RAW.TRIPS_GREEN_2024_11  |  COUNT = 52222
# ✅ Cargado: RAW.TRIPS_GREEN_2024_12
# ✅ Cargado: RAW.TRIPS_GREEN_2024_12  |  COUNT = 53994
# ✅ Cargado: RAW.TRIPS_GREEN_2025_01
# ✅ Cargado: RAW.TRIPS_GREEN_2025_01  |  COUNT = 48326
# ✅ Cargado: RAW.TRIPS_GREEN_2025_02
# ✅ Cargado: RAW.TRIPS_GREEN_2025_02  |  COUNT = 46621
# ✅ Cargado: RAW.TRIPS_GREEN_2025_03
# ✅ Cargado: RAW.TRIPS_GREEN_2025_03  |  COUNT = 51539
# ✅ Cargado: RAW.TRIPS_GREEN_2025_04
# ✅ Cargado: RAW.TRIPS_GREEN_2025_04  |  COUNT = 52132
# ✅ Cargado: RAW.TRIPS_GREEN_2025_05
# ✅ Cargado: RAW.TRIPS_GREEN_2025_05  |  COUNT = 55399
# ✅ Cargado: RAW.TRIPS_GREEN_2025_06
# ✅ Cargado: RAW.TRIPS_GREEN_2025_06  |  COUNT = 49390
# ✅ Cargado: RAW.TRIPS_GREEN_2025_07
# ✅ Cargado: RAW.TRIPS_GREEN_2025_07  |  COUNT = 48205
# ✅ Cargado: RAW.TRIPS_GREEN_2025_08
# ✅ Cargado: RAW.TRIPS_GREEN_2025_08  |  COUNT = 46306
#
# Resumen:
#   Meses con error: 0
